# %% [markdown]
# # 表征

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from matplotlib import pylab

# %% [markdown]
# ## NMR

# %%
data_file_name = r'./data/sample-1/NMR.csv'
nmr = pd.read_csv(
    data_file_name, 
    delim_whitespace=True
)
# Remove rows when you have default index.
nmr = nmr.drop(0)

nmr = nmr.astype(float)
nmr.head(5)
# Out:
#         ti:  single_pulse
# 1  14.38393           0.0
# 2  14.38336           0.0
# 3  14.38279           0.0
# 4  14.38221           0.0
# 5  14.38164           0.0

# %%
params = {
    'legend.fontsize': 20,
    'figure.figsize': (20, 10),
    'axes.labelsize': 24,
    'axes.titlesize':24,
    'xtick.labelsize':24,
    'ytick.labelsize':20
    
}
pylab.rcParams.update(params)

# %%
x = nmr[nmr.columns[0]]
y = nmr[nmr.columns[1]]
plt.xlabel('Chemical Shift (ppm)',
           fontweight='light', 
           fontname="Arial",
           labelpad=15)
plt.ylabel(' ')
plt.title('NMR',
          fontname="Arial",)
plt.plot(x, y)
plt.xlim(max(x), min(x))
plt.xlim([8, 0])
plt.yticks([])
plt.show()

# %% [markdown]
# ### NMR series

# %%
data_file_name = r'./data/sample-1/NMR.csv'
nmr = pd.read_csv(
    data_file_name, 
    delim_whitespace=True
)
# Remove rows when you have default index.
nmr = nmr.drop(0)

nmr = nmr.astype(float)
nmr.head(5)

# %% [markdown]
# ## GPC

# %%
data_file_name = r'./data/SY207/NMR.csv'
nmr = pd.read_csv(
    data_file_name, 
    delim_whitespace=True
)
# Remove rows when you have default index.
nmr = nmr.drop(0)

nmr = nmr.astype(float)
nmr.head(5)

# %% [markdown]
# ## TG/DTA

# %% [markdown]
# ## DSC

# %% [markdown]
# ## Density

# %% [markdown]
# # 测试

# %% [markdown]
# ## SAXS - I

# %% [markdown]
# ## SAXS - II
